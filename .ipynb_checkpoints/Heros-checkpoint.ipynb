# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn
seaborn.set()
heros = pd.read_csv('heros.csv')


heros['最大攻速'] = [float(i[:-1]) for i in heros['最大攻速']]
heros = heros.dropna(axis=1)
# heros.hist() assignment!!!@!!!!!!@@!@!@@@@!@!@!@!@!@!@!@!@!@!@!@12!@!
topthree = heros.sort_values('最高物攻',ascending=False,axis=0)
topthree.iloc[:3,:3]
heros.groupby('攻击范围').count().iloc[:,:1]
for i in heros.groupby('主要定位')['最大生命']:
    print(i)

# a = []
# for i in range(len(heros.query("(主要定位=='坦克')"))):
#     a.append(heros.query("(主要定位=='坦克')").iloc[i][1])
plt.hist(heros.groupby('主要定位')['最大生命'].iloc[0])
plt.title("Max Health of Tanks")
plt.xlabel('HP')
plt.ylabel('No. of tanks')
plt.show()
# Out:
# ('刺客', 52    7000
# 53    5483
# 54    5655
# 64    5968
# 65    6205
# 66    6232
# Name: 最大生命, dtype: int64)
# ('坦克', 0     7350
# 2     8341
# 3     8476
# 7     8611
# 8     9328
# 9     7669
# 12    8638
# 14    8073
# 15    8581
# 17    8057
# Name: 最大生命, dtype: int64)
# ('射手', 19    5986
# 20    5584
# 21    5989
# 22    5725
# 23    6014
# 24    5898
# 25    5710
# 26    5669
# 27    5799
# 68    5611
# Name: 最大生命, dtype: int64)
# ('战士', 1     7000
# 4     7344
# 5     8050
# 13    6264
# 18    7107
# 30    6612
# 50    5397
# 51    6732
# 55    7420
# 56    7140
# 57    6585
# 58    6900
# 59    7473
# 60    7516
# 61    6210
# 62    7155
# 63    7268
# 67    6700
# Name: 最大生命, dtype: int64)
# ('法师', 6     6164
# 16    7176
# 28    5471
# 29    5037
# 31    5584
# 32    5824
# 33    5583
# 34    5399
# 35    5429
# 36    5655
# 37    6014
# 38    5611
# 40    5994
# 41    5916
# 42    5513
# 43    5799
# 44    6165
# 45    6703
# 46    6280
# Name: 最大生命, dtype: int64)
# ('辅助', 10    8149
# 11    6835
# 39    6811
# 47    5399
# 48    7107
# 49    5910
# Name: 最大生命, dtype: int64)
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-22-b9976c26824c> in <module>
#      20 # for i in range(len(heros.query("(主要定位=='坦克')"))):
#      21 #     a.append(heros.query("(主要定位=='坦克')").iloc[i][1])
# ---> 22 plt.hist(heros.groupby('主要定位')['最大生命'].iloc[0])
#      23 plt.title("Max Health of Tanks")
#      24 plt.xlabel('HP')
#
# /Applications/anaconda3/lib/python3.7/site-packages/pandas/core/groupby/groupby.py in __getattr__(self, attr)
#     561             return self[attr]
#     562         if hasattr(self.obj, attr):
# --> 563             return self._make_wrapper(attr)
#     564
#     565         raise AttributeError(
#
# /Applications/anaconda3/lib/python3.7/site-packages/pandas/core/groupby/groupby.py in _make_wrapper(self, name)
#     602                 "using the 'apply' method".format(kind, name, type(self).__name__)
#     603             )
# --> 604             raise AttributeError(msg)
#     605
#     606         self._set_group_selection()
#
# AttributeError: Cannot access callable attribute 'iloc' of 'SeriesGroupBy' objects, try using the 'apply' method
